# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pydataset import data
import env

# %%
#Use the iris database to answer the following quesitons

# %%
iris = data('iris')

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.info(), iris.dtypes, iris.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB
# (None,
#  Sepal.Length    float64
#  Sepal.Width     float64
#  Petal.Length    float64
#  Petal.Width     float64
#  Species          object
#  dtype: object,
#  (150, 5))

# %%
data('iris', show_doc=True)
# Out:
# iris
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Edgar Anderson's Iris Data
#
# ### Description
#
# This famous (Fisher's or Anderson's) iris data set gives the measurements in
# centimeters of the variables sepal length and width and petal length and
# width, respectively, for 50 flowers from each of 3 species of iris. The
# species are _Iris setosa_, _versicolor_, and _virginica_.
#
# ### Usage
#
#     iris
#     iris3
#
# ### Format
#
# `iris` is a data frame with 150 cases (rows) and 5 variables (columns) named
# `Sepal.Length`, `Sepal.Width`, `Petal.Length`, `Petal.Width`, and `Species`.
#
# `iris3` gives the same data arranged as a 3-dimensional array of size 50 by 4
# by 3, as represented by S-PLUS. The first dimension gives the case number
# within the species subsample, the second the measurements with names `Sepal
# L.`, `Sepal W.`, `Petal L.`, and `Petal W.`, and the third the species.
#
# ### Source
#
# ...

# %%
#1 What does the distribution of petal lengths look like?

# %%
iris.sample(5)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 83            5.8          2.7           3.9          1.2  versicolor
# 87            6.7          3.1           4.7          1.5  versicolor
# 90            5.5          2.5           4.0          1.3  versicolor
# 102           5.8          2.7           5.1          1.9   virginica
# 119           7.7          2.6           6.9          2.3   virginica

# %%
sns.histplot(iris['Petal.Length'], kde = True)
# Out:
# <AxesSubplot:xlabel='Petal.Length', ylabel='Count'>

# %%
sns.histplot(data = iris, x= 'Petal.Length', hue = 'Species')
# Out:
# <AxesSubplot:xlabel='Petal.Length', ylabel='Count'>

# %%
sns.relplot(data = iris, x= 'Petal.Length', y = 'Petal.Width')

# %%
#there appears to be a positive correlation

# %%
#2Would it be reasonable to predict species based on sepal width and sepal length? 
#For this, you'll visualize two numeric columns through the lense of a categorical column.

#Satosa Yes, the other two, No

# %%
iris.sample(5)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 99            5.1          2.5           3.0          1.1  versicolor
# 144           6.8          3.2           5.9          2.3   virginica
# 64            6.1          2.9           4.7          1.4  versicolor
# 119           7.7          2.6           6.9          2.3   virginica
# 19            5.7          3.8           1.7          0.3      setosa

# %%
iris['Sepal.Ratio'] = (iris['Sepal.Length']/iris['Sepal.Width']) #play

# %%
#play
plt.subplot(311)
sns.boxplot(data = iris, x= 'Sepal.Length', y = 'Species')

plt.subplot(312)
sns.boxplot(data = iris, x= 'Sepal.Width', y = 'Species')

plt.subplot(313)
sns.boxplot(data = iris, x= 'Sepal.Ratio', y = 'Species')

plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
sns.scatterplot(data = iris, x = 'Sepal.Length', y = 'Sepal.Width', hue = 'Species')
#2 answer 
#3 Not ideal
# Out:
# <AxesSubplot:xlabel='Sepal.Length', ylabel='Sepal.Width'>

# %%
plt.figure(figsize = (10,8))

plt.subplot(2,2,1)
sns.scatterplot(data = iris, x = 'Petal.Length', y = 'Petal.Width', hue = 'Species') 

plt.subplot(2,2,2)
sns.scatterplot(data = iris, x = 'Sepal.Length', y = 'Petal.Width', hue = 'Species') 

plt.subplot(2,2,3)
sns.scatterplot(data = iris, x = 'Petal.Length', y = 'Sepal.Width', hue = 'Species') 

plt.subplot(2,2,4)
sns.scatterplot(data = iris, x = 'Sepal.Length', y = 'Sepal.Width', hue = 'Species')

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)


#4 Which features would be best used to predict species? 
#Petal vs Petalwould be most appropriate for differentiating

# %%
sns.pairplot(data = iris, hue = 'Species')

# %%
anscombe = sns.load_dataset('anscombe')

# %%
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe.dtypes
# Out:
# dataset     object
# x          float64
# y          float64
# dtype: object

# %%
anscombe.describe()
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %%
anscombe.groupby('dataset').describe() #class method
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
an_summary = anscombe.groupby(anscombe['dataset']).agg(['min', 'max', 'mean'])
an_summary
# Out:
#            x                y
#          min   max mean   min    max      mean
# dataset
# I        4.0  14.0  9.0  4.26  10.84  7.500909
# II       4.0  14.0  9.0  3.10   9.26  7.500909
# III      4.0  14.0  9.0  5.39  12.74  7.500000
# IV       8.0  19.0  9.0  5.25  12.50  7.500909

# %%
an_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, I to IV
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   (x, min)   4 non-null      float64
#  1   (x, max)   4 non-null      float64
#  2   (x, mean)  4 non-null      float64
#  3   (y, min)   4 non-null      float64
#  4   (y, max)   4 non-null      float64
#  5   (y, mean)  4 non-null      float64
# dtypes: float64(6)
# memory usage: 224.0+ bytes

# %%
sns.relplot(data=anscombe, x = 'x', y = 'y', col ='dataset')

# %%
sns.barplot(data = an_summary)
# Out:
# <AxesSubplot:>

# %%
sns.lmplot(data=anscombe, x = 'x', y = 'y', col ='dataset')

# %%
an_summary.columns.levels
# Out:
# FrozenList([['x', 'y'], ['min', 'max', 'mean']])

# %%
an_summary.columns
# Out:
# MultiIndex([('x',  'min'),
#             ('x',  'max'),
#             ('x', 'mean'),
#             ('y',  'min'),
#             ('y',  'max'),
#             ('y', 'mean')],
#            )

# %% [markdown]
# ## Playing with Multiindexes

# %%
#ax = an_summary.unstack(level=1).plot(kind='bar', rot=0, figsize=(9, 7))
#plt.tight_layout()

# %%
#sns.barplot(data = an_summary, x = ['an_summary.groupby(level=0)'], hue = 'an_summary.groupby(level=1)')

# %%
# index = pandas.MultiIndex.from_product(
#     [groups, sexes, means], 
#    names=['Group', 'Sex', 'Mean']
# )

# fg = seaborn.factorplot(x='Group', y='val', hue='Mean', 
#                         col='Sex', data=data, kind='bar')
# fg.set_xlabels('')

# %%
#sns.barplot(data = an_summary, x = an_summary.index.level[0])

# %%
#an_summary.unstack()

# %% [markdown]
# ## Return to Assingment

# %%
#Load the InsectSprays dataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
ins_spray = data('InsectSprays')

# %%
ins_spray.sample(5)
# Out:
#     count spray
# 53      3     E
# 10     20     A
# 56      1     E
# 29      3     C
# 2       7     A

# %%
ins_spray.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 1 to 72
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   72 non-null     int64
#  1   spray   72 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.7+ KB

# %%
#data('InsectSprays', show_doc=True)

# %%
ins_spray.groupby('spray').mean()
# Out:
#            count
# spray
# A      14.500000
# B      15.333333
# C       2.083333
# D       4.916667
# E       3.500000
# F      16.666667

# %%
sns.boxplot(data= ins_spray, x = 'count', y = 'spray')
plt.title('Insect Spray Effectivness')
# Out:
# Text(0.5, 1.0, 'Insect Spray Effectivness')

# %%
#Load the swiss dataset and read it's documentation. The swiss dataset is available from pydatset rather than seaborn. Create visualizations to answer the following questions:

# %%
swiss = data('swiss')

# %%
#data('swiss', show_doc = True)

# %%
swiss.sample(5)
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# ValdeTravers       67.6         18.7           25          7      8.65
# Payerne            74.2         58.1           14          8      5.23
# La Chauxdfnd       65.7          7.7           29         11     13.79
# Grandson           71.7         34.0           17          8      3.30
# Aubonne            66.9         67.5           14          7      2.27
#
#               Infant.Mortality
# ValdeTravers              19.5
# Payerne                   23.8
# La Chauxdfnd              20.5
# Grandson                  20.0
# Aubonne                   19.1

# %%
swiss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, Courtelary to Rive Gauche
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fertility         47 non-null     float64
#  1   Agriculture       47 non-null     float64
#  2   Examination       47 non-null     int64
#  3   Education         47 non-null     int64
#  4   Catholic          47 non-null     float64
#  5   Infant.Mortality  47 non-null     float64
# dtypes: float64(4), int64(2)
# memory usage: 2.6+ KB

# %% [markdown]
# #3

# %%
    #Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic) Ans: See Below
    #Does whether or not a province is Catholic influence fertility? Ans:No correlation
    #What measure correlates most strongly with fertility? Ans: Examination + Education

# %%
sns.scatterplot(data = swiss, x = 'Catholic', y = swiss.index) #pick cutoff for yes or no catholic boolean, 50%
#this is for me as a data scientist, I would never present this
# Out:
# <AxesSubplot:xlabel='Catholic'>

# %%
cath = swiss.Catholic > 50

# %%
is_cath = swiss[cath].Fertility.mean()
is_cath
# Out:
# 76.46111111111111

# %%
swiss[cath == False].Fertility.mean()
# Out:
# 66.22068965517242

# %%
sns.pairplot(swiss)

# %%
swiss.corr().Fertility
# Out:
# Fertility           1.000000
# Agriculture         0.353079
# Examination        -0.645883
# Education          -0.663789
# Catholic            0.463685
# Infant.Mortality    0.416556
# Name: Fertility, dtype: float64

# %%
#4

# %%
#Using the chipotle dataset from the previous exercise, 
#create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
import env

# %%
chp = pd.read_sql('SELECT * FROM orders', env.get_db_url('chipotle') )
chp.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
chp.item_price = chp.item_price.str.replace('$', '').str.strip().astype(dtype = 'float') #cleaning
# Out:
# /var/folders/lh/dkl_j44s5s192k6tt8pqtrdh0000gn/T/ipykernel_4264/433354939.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chp.item_price = chp.item_price.str.replace('$', '').str.strip().astype(dtype = 'float')

# %%
chp.groupby('item_name')[['quantity']].sum().sort_values('quantity', ascending = False).head(4)
# Out:
#                      quantity
# item_name
# Chicken Bowl              761
# Chicken Burrito           591
# Chips and Guacamole       506
# Steak Burrito             386

# %%
total_sold= chp.groupby('item_name')[['quantity']].sum().sort_values('quantity', ascending = False)
total_sold.head()
# Out:
#                      quantity
# item_name
# Chicken Bowl              761
# Chicken Burrito           591
# Chips and Guacamole       506
# Steak Burrito             386
# Canned Soft Drink         351

# %%
avg_cost_per_item = chp.groupby('item_name')[['item_price']].mean()
avg_cost_per_item.head()
# Out:
#                        item_price
# item_name
# 6 Pack Soft Drink        6.610185
# Barbacoa Bowl           10.187273
# Barbacoa Burrito         9.832418
# Barbacoa Crispy Tacos   10.928182
# Barbacoa Salad Bowl     10.640000

# %%
rev = total_sold.merge(avg_cost_per_item, how = 'left', on = 'item_name')

# %%
rev.head(4)
# Out:
#                      quantity  item_price
# item_name
# Chicken Bowl              761   10.113953
# Chicken Burrito           591   10.082857
# Chips and Guacamole       506    4.595073
# Steak Burrito             386   10.465842

# %%
rev['total_rev'] = (rev.quantity * rev.item_price)
rev.head(4)
# Out:
#                      quantity  item_price    total_rev
# item_name
# Chicken Bowl              761   10.113953  7696.718361
# Chicken Burrito           591   10.082857  5958.968571
# Chips and Guacamole       506    4.595073  2325.106973
# Steak Burrito             386   10.465842  4039.815163

# %%
rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Chicken Bowl to Veggie Crispy Tacos
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   quantity    50 non-null     int64
#  1   item_price  50 non-null     float64
#  2   total_rev   50 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.6+ KB

# %%
rev_barplot = rev.sort_values('total_rev', ascending = False).head(4)
rev_barplot
# Out:
#                  quantity  item_price    total_rev
# item_name
# Chicken Bowl          761   10.113953  7696.718361
# Chicken Burrito       591   10.082857  5958.968571
# Steak Burrito         386   10.465842  4039.815163
# Steak Bowl            221   10.711801  2367.308009

# %%
sns.barplot(data = rev_barplot, x = rev_barplot.index, y = 'total_rev')
# Out:
# <AxesSubplot:xlabel='item_name', ylabel='total_rev'>

# %%
# Load the sleepstudy data and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
sleep =  data('sleepstudy')

# %%
sleep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 1 to 180
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Reaction  180 non-null    float64
#  1   Days      180 non-null    int64
#  2   Subject   180 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 5.6 KB

# %%
sleep.sample(5)
# Out:
#      Reaction  Days  Subject
# 61   283.8424     0      333
# 98   416.6923     7      337
# 133  326.8785     2      352
# 50   371.5811     9      331
# 5    356.8519     4      308

# %%
sns.lineplot(data = sleep, x='Days', y = 'Reaction')
plt.title('Exhaustion vs Reaction Time, Average')
# Out:
# Text(0.5, 1.0, 'Exhaustion vs Reaction Time, Average')

# %%
sns.lineplot(data = sleep, x='Days', y = 'Reaction', hue = 'Subject')
plt.title('Exhaustion vs Reaction Time, Individual')
# Out:
# Text(0.5, 1.0, 'Exhaustion vs Reaction Time, Individual')

# %%
sns.lineplot(data = sleep, x='Days', y = 'Reaction')
sns.lineplot(data = sleep, x='Days', y = 'Reaction', hue = 'Subject')
plt.title('Combined')
# Out:
# Text(0.5, 1.0, 'Combined')
